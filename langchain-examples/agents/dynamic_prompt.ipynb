# %%
from langchain.messages import HumanMessage
from typing import TypedDict
from langchain.agents import create_agent
from langchain.agents.middleware import dynamic_prompt, ModelRequest
from pprint import pprint

class Context(TypedDict):
    user_role: str

@dynamic_prompt
def user_role_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_role = request.runtime.context.get('user_role', 'user')
    base_prompt = 'You are a helpful assistant.'

    if user_role == 'expert':
        return f'{base_prompt} Answer questions briefly, without elaborating on simple concepts.'
    elif user_role == 'beginner':
        return f'{base_prompt} Provide detailed explanations of professional concepts so that even beginners can understand them.'

    return base_prompt

agent = create_agent(
    model='deepseek-chat',
    middleware=[user_role_prompt],
    context_schema=Context,
)

# %%
expert_response = agent.invoke(
    {'messages': [HumanMessage('Explain machine learning.')]}, context={'user_role': 'expert'}
)
beginner_response = agent.invoke(
    {'messages': [HumanMessage('Explain machine learning.')]}, context={'user_role': 'beginner'}
)

# %%
for msg in expert_response['messages']:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Explain machine learning.
# ================================== Ai Message ==================================
#
# Machine learning is a branch of artificial intelligence where computers learn from data to make predictions or decisions without being explicitly programmed for each task.

# %%
for msg in beginner_response['messages']:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Explain machine learning.
# ================================== Ai Message ==================================
#
# Of course! Let's break down machine learning (ML) in a way that's easy to grasp, even if you're completely new to the topic.
#
# ### The Core Idea in One Sentence
# **Machine learning is a way for computers to learn from data and make decisions or predictions without being explicitly programmed for every single rule.**
#
# Think of it like this: Instead of a programmer writing thousands of "if-then" instructions (e.g., *"if pixel 1 is dark and pixel 2 is light, then it might be an edge..."*), we give the computer many examples and let it figure out the patterns on its own.
#
# ---
#
# ### A Simple Analogy: Learning to Recognize Dogs
# Imagine you want to teach a young child what a dog is.
#
# 1.  **Traditional Programming:** You'd write a detailed manual: "It has four legs, fur, a tail, barks, etc." This is rigid. What about a three-legged dog? A hairless breed? It fails easily.
# 2.  **Machine Learning Approach:** You show the child **many pictures**—some labeled "dog," some labeled "not a dog" (cat, car, sandwich). The child's brain starts to notice patterns: snout shape, ear position, body structure. After seeing enough examples, the child can **generalize** and correctly identify a dog they've never seen before.
#
# In ML:
# *   The **child** is the **computer program (model)**.
# *   The **pictures** are the **data**.
# *   The **labels** ("dog"/"not dog") are the **training signal**.
# *   The process of learning from examples is **training**.
# *   Correctly identifying a new picture is a **prediction**.
#
# ---
#
# ### The Three Main Types of Machine Learning
#
# | Type | How It Works | Real-World Example |
# | :--- | :--- | :--- |
# | **1. Supervised Learning** | The most common type. The model learns from **labeled data** (data with the "answer key"). It finds the connection between the input data and the known output. | **Spam Filter:** You show the model thousands of emails pre-labeled as "spam" or "not spam." It learns the patterns (words, senders) that define spam and filters new emails. |
# | **2. Unsupervised Learning** | The model finds hidden patterns or structures in **unlabeled data**. There's no "answer key"; the goal is to explore and organize the data. | **Customer Segmentation:** A retailer gives the model purchase data (no labels). The model might group customers into clusters like "budget shoppers," "luxury buyers," and "bulk purchasers" based on spending habits. |
# | **3. Reinforcement Learning** | The model learns by **trial and error**, receiving rewards or penalties for its actions. It learns a strategy (policy) to maximize total reward over time. | **Teaching a Robot to Walk:** The program (agent) tries movements. If it moves forward, it gets a **reward (+1)**. If it falls, it gets a **penalty (-10)**. It learns to walk by discovering which sequences of movements yield the highest reward. |
#
# ---
#
# ### The Basic Workflow: How an ML Project Happens
# 1.  **Collect & Prepare Data:** Get relevant data (e.g., historical house prices, customer records, sensor readings). Clean it (fix errors, handle missing values). This is often 80% of the work!
# 2.  **Choose a Model:** Pick an algorithm (a mathematical recipe for learning). Different problems need different models (e.g., decision trees, neural networks).
# 3.  **Train the Model:** Feed the prepared data into the model. The model adjusts its internal parameters to best fit the data. It's like tuning a complex radio until the signal is clear.
# 4.  **Evaluate the Model:** Test it on **new, unseen data** to see how accurate its predictions are. A model that only memorizes the training data but fails on new data is useless (this is called **overfitting**).
# 5.  **Make Predictions / Deploy:** Use the trained model to make predictions on real-world data (e.g., recommend a product, diagnose a disease from an X-ray, forecast stock trends).
#
# ---
#
# ### Common Examples in Everyday Life
# *   **Recommendation Systems:** Netflix suggesting shows, YouTube recommending videos, Amazon's "customers who bought this also bought..."
# *   **Voice Assistants:** Siri, Alexa, and Google Assistant understanding your speech.
# *   **Fraud Detection:** Your bank's system flagging an unusual transaction.
# *   **Navigation Apps:** Google Maps predicting your travel time based on traffic patterns.
# *   **Face Recognition:** Unlocking your phone or tagging friends in photos.
#
# ### Why It's a Big Deal
# Machine learning excels at finding complex, subtle patterns in massive amounts of data—patterns that would be impossible for a human to manually code for. It's the driving force behind most modern "AI" you interact with.
#
# **In essence, machine learning is about building systems that *improve with experience*. It's a powerful tool that is transforming every industry, from healthcare and finance to entertainment and transportation.**
