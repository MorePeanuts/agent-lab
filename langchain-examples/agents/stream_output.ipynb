# %%
from langchain.messages import AIMessage, HumanMessage
from langchain.agents import create_agent

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model="deepseek-chat",
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)

# %%
for chunk in agent.stream(
    {"messages": [{"role": "user", "content": "what is the weather in sf"}]},
    stream_mode='values',
):
    # Each chunk contains the full state at that point
    latest_message = chunk["messages"][-1]
    if latest_message.content:
        if isinstance(latest_message, HumanMessage):
            print(f"User: {latest_message.content}")
        elif isinstance(latest_message, AIMessage):
            print(f"Agent: {latest_message.content}")
    elif latest_message.tool_calls:
        print(f"Calling tools: {[tc['name'] for tc in latest_message.tool_calls]}")
# Out:
# User: what is the weather in sf
# Agent: I'll check the weather in San Francisco for you.
# Agent: According to the weather service, it's always sunny in San Francisco! This appears to be a fixed response rather than current weather data. For more accurate, real-time weather information, you might want to check a dedicated weather website or app for the most up-to-date conditions in San Francisco.

# %%
# TODO: More detailed explanation
